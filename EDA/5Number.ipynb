# %%
import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,120,151,189]
mini,Q1,median,Q3,maxi=np.quantile(lst_marks,[0.0,0.25,0.50,0.75,1.0])

# %%
mini,Q1,median,Q3,maxi
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >
